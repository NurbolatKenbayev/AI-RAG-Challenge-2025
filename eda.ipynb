# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ques_path = '../68a58892b4058539485342/questions_public.xlsx'
ques_path = '../68a86b9f5d944822407386.xlsx'

df = pd.read_excel(ques_path)

# %%
pd.options.display.max_colwidth = 150

df.head(15)
# Out:
#     id block  \
# 0    1  Both
# 1    2  Both
# 2    3   OCR
# 3    4    AR
# 4    5   OCR
# 5    6    AR
# 6    7   OCR
# 7    8   OCR
# 8    9    AR
# 9   10  Both
# 10  11  Both
# 11  12   OCR
# 12  13  Both
# 13  14   OCR
# 14  15   OCR
#
#                                                                                                                            full_question  \
# 0                                                                                     По какому адресу зарегистрирован АО "ЛОТТЕ Рахат"?
# 1          Какие цели устойчивого развития ООН являются приоритетными для АО "Казахтелеком"? Перечислите номера этих целей через запятую
# 2                          Какая была выручка у АО "Кеденстранссервис" за 2024 год (в млрд тенге, округляя до 2-х знаков после запятой)?
# 3   Какое у Казахстан Темир Жолы фактическое значение по показателю рентабельности среднего задействованного капитала (в %) в 2023 году?
# 4                    Сколько тонн составили прямые выбросы СО2 с месторождения Матин в 2024 году (округляя до 2-х знаков после запятой)?
# 5                    Какая аудиторская компания проводила аудит финансовой отчетности АО "Teniz Capital Investment Banking" в 2024 году?
# 6        Согласно ключевым ценовым отметкам золота в отчете BASS Gold, сколько составила средняя цена за унцию в 4-м квартале 2024 года?
# 7             Какую сумму составила валовая прибыль ТОО “Компания Фаэтон” за 2024 год (млн тенге, округляя до 2-х знаков после запятой)?
# 8                                                                                         Сколько вертолетов есть у компании Air Astana?
# 9       В среднем сколько маршрутов есть на каждую из стран-направлений у всей группы Air Astana (округляя до 2-х знаков после запятой)?
# 10                                                                  Сколько наименований различной продукции выпускает АО "ЛОТТЕ Рахат"?
# 11                                      Какую сумму составили расходы связанные с износом за 2024 год у АО “Матен Петролеум”(тыс тенге)?
# 12                                          Какая компания проводила аудит годовой отчетности АО “Банк Развития Казахстана” за 2024 год?
# 13              Какой процент у города Уральск в реализации продукции АО “Баян Сулу” в 2024 году (округляя до 2-х знаков после запятой)?
# 14                                                     На какую сумму у АО "АзияАгроФуд" есть нефинансовые обязательства (в тыс. тенге)?
#
#    answer_type
# 0          str
# 1          str
# 2        float
# 3        float
# 4        float
# 5          str
# 6          int
# 7        float
# 8          int
# 9        float
# 10         int
# 11         int
# 12         str
# 13       float
# 14         int

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             200 non-null    int64
#  1   block          200 non-null    object
#  2   full_question  200 non-null    object
#  3   answer_type    200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %%
# id_ = 197 # success
# id_ = 194 # success
# id_ = 171
# id_ = 196
# id_ = 185 # fail
# id_ = 182 # success
# id_ = 11 # success
id_ = 200


df[df["id"] == id_]
# Out:
#       id block  \
# 199  200  Both
#
#                                                                                                        full_question  \
# 199  Какова суммарная доля участия членов Совета Директоров в АО “Баян Сулу” (округляя до 2-х знаков после запятой)?
#
#     answer_type
# 199       float

# %%
for index, row in df.iterrows():
    print(index)
    print(row)
# Out:
# 0
# id                                                                                    1
# block                                                                               OCR
# full_question    Какой организацией представлен АО «НК Қазақстан Темір Жолы» в Венгрии?
# answer_type                                                                         str
# Name: 0, dtype: object
# 1
# id                                                                                2
# block                                                                           OCR
# full_question    Какая цель у КТЖ по показателю (в баллах) рейтинг ESG на 2032 год?
# answer_type                                                                     int
# Name: 1, dtype: object
# 2
# id                                                                                                                                                  3
# block                                                                                                                                              AR
# full_question    Какое у Казахстан Темир Жолы фактическое значение по показателю рентабельности среднего задействованного капитала (в %) в 2024 году?
# answer_type                                                                                                                                     float
# Name: 2, dtype: object
# 3
# id                                                                                              4
# block                                                                                        Both
# full_question    В скольких месяцах 2024 года добыча руды превысила 5 млн тонн у ТОО "Bass Gold"?
# answer_type                                                                                   int
# Name: 3, dtype: object
# 4
# id                                                                    5
# block                                                               OCR
# full_question    Какую должность занимает Им Вонхёк в АО "ЛОТТЕ Рахат"?
# answer_type                                                         str
# Name: 4, dtype: object
# 5
# id                                                                                      6
# block                                                                                Both
# full_question    Сколько физлиц нерезидентов среди аффилированных лиц у АО "ЛОТТЕ Рахат"?
# answer_type                                                                           int
# Name: 5, dtype: object
# 6
# id                                                                                                       7
# block                                                                                                   AR
# full_question    У какой компании капитальные затраты были выше: ТОО "Bass Gold" или АО "МАТЕН ПЕТРОЛЕУМ"?
# answer_type                                                                                            str
# Name: 6, dtype: object
# 7
# id                                                                                                                          8
# block                                                                                                                     OCR
# full_question    Сколько тенге составляет обязательный размер дивидендов по привелигированным акциям в расчете на одну акцию?
# answer_type                                                                                                               int
# Name: 7, dtype: object
# 8
# id                                                                                                                               9
# block                                                                                                                           AR
# full_question    Какая сумма в тенге налоговых убытков была у группы компаний АО «Матен Петролеум» на момент 31 декабря 2024 года?
# answer_type                                                                                                                    int
# Name: 8, dtype: object
# 9
# id                                                                                     10
# block                                                                                Both
# full_question    Сколько всего тонн выбросов CO2 произвёл объект НПС Каратон в 2024 году?
# answer_type                                                                         float
# Name: 9, dtype: object
# 10
# id                                                                                      11
# block                                                                                 Both
# full_question    Какая еженедельная частота рейсов было в 2024 году у компании FlyArystan?
# answer_type                                                                            int
# Name: 10, dtype: object
# 11
# id                                                                                  12
# block                                                                             Both
# full_question    Сколько лет срок полезной службы воздушного судна в учётной политике?
# answer_type                                                                        int
# Name: 11, dtype: object
# 12
# id                                                                         13
# block                                                                     OCR
# full_question    Кто является Управляющим директором по финансам АО "НК "ҚТЖ"
# answer_type                                                               str
# Name: 12, dtype: object
# 13
# id                                                             14
# block                                                         OCR
# full_question    Кто главный бухгалтер в АО "AsiaAgroFood" (ФИО)?
# answer_type                                                   str
# Name: 13, dtype: object
# 14
# id                                                                     15
# block                                                                  AR
# full_question    Сколько работников было в АО "Казахтелеком" в 2024 году?
# answer_type                                                           int
# Name: 14, dtype: object

# %%
row
# Out:
# id                                                                     15
# block                                                                  AR
# full_question    Сколько работников было в АО "Казахтелеком" в 2024 году?
# answer_type                                                           int
# Name: 14, dtype: object

# %%
row["id"]
# Out:
# 15

# %%
ans = "4"
row["answer_type"]
# Out:
# 'int'

# %%
type_str = "float"
answer = "4"
eval(f"{type_str}('{answer}')")
# Out:
# 4.0
