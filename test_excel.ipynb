# %%
from excel import apply_chunking_excel

excel_path = "C:/Users/artma/Desktop/hackathons/AI-RAG-Challenge-2025/dataset/68a58892b4058539485342/Dataset/AsiaAgroFood/aafdfm1_2025_cons_rus.xlsx"

chunks = apply_chunking_excel(
    excel_path=excel_path
)
# Out:
# 2025-08-23 23:51:00,082 - excel.apply_chunking_excel - INFO - Semantic segmentation for given Excel document (parsing)...
# 2025-08-23 23:51:00,255 - excel.apply_chunking_excel - INFO - Chunking...

# %%
chunks[0]
# Out:
# DocChunk(text='<table><tbody><tr><th>АО &quot;АзияАгроФуд&quot;</th></tr><tr><td>ПРОМЕЖУТОЧНЫЙ СОКРАЩЁННЫЙ КОНСОЛИДИРОВАННЫЙ ОТЧЁТ О ФИНАНСОВОМ ПОЛОЖЕНИИ</td></tr><tr><td>По состоянию на 31 марта 2025 года</td></tr></tbody></table>\n<table><tbody><tr><th>в тыс.тенге</th><th>Прим.</th><th>31.03.2025 (неаудировано)</th><th>31.12.2024 (неаудировано)</th></tr></tbody></table>\n<table><tbody><tr><th>АКТИВЫ</th></tr></tbody></table>\n<table><tbody><tr><th>Внеоборотные активы</th></tr><tr><td>Основные средства</td></tr><tr><td>Нематериальные активы</td></tr><tr><td>Биологические активы</td></tr><tr><td>Инвестиции в дочерние компании</td></tr><tr><td>Прочие внеоборотные активы</td></tr><tr><td>Итого внеоборотных активов</td></tr><tr><td>Оборотные активы</td></tr><tr><td>Биологические активы</td></tr><tr><td>Запасы</td></tr><tr><td>Торговая и прочая дебиторская задолженность</td></tr><tr><td>Предоплата по подоходному налогу</td></tr><tr><td>Предоплата по прочим налогам и обязательным платежам
# ...
